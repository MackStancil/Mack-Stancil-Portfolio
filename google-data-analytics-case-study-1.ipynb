# %% [markdown]
# # Case Study: How does a bike-share navigate speedy success?

# %% [markdown]
# # Introduction
# Google Data Analytics Career Certificate Capstone project.
#
# ## Case Study 1
# **Scenario:**
# You are a junior data analyst working on the marketing analyst team at Cyclistic, a bike-share
# company in Chicago. The director of marketing believes the company’s future success
# depends on maximizing the number of annual memberships. Therefore, your team wants to
# understand how casual riders and annual members use Cyclistic bikes differently. From these
# insights, your team will design a new marketing strategy to convert casual riders into annual
# members. But first, Cyclistic executives must approve your recommendations, so they must be
# backed up with compelling data insights and professional data visualizations.
#
# ## Characters and Teams
# * **Cyclistic:** A bike-share program that features more than 5,800 bicycles and 600 docking stations. Cyclistic sets itself apart by also offering reclining bikes, hand tricycles, and cargo bikes, making bike-share more inclusive to people with disabilities and riders who can’t use a standard two-wheeled bike. The majority of riders opt for traditional bikes; about 8% of riders use the assistive options. Cyclistic users are more likely to ride for leisure, but about 30% use the bikes to commute to work each day
#
# * **Lily Moreno:** The director of marketing and your manager. Moreno is responsible forthe development of campaigns and initiatives to promote the bike-share program.These may include email, social media, and other channels.
#
# * **Cyclistic marketing analytics team:** A team of data analysts who are responsible forcollecting, analyzing, and reporting data that helps guide Cyclistic marketing strategy.You joined this team six months ago and have been busy learning about Cyclistic’smission and business goals—as well as how you, as a junior data analyst, can help Cyclistic achieve them.
#
# * **Cyclistic executive team:** The notoriously detail-oriented executive team will decide whether to approve the recommended marketing program.

# %% [markdown]
# # Ask
#
# ### Guiding Questions:
# * **What is the problem you are trying to solve?**
#
# The goal of this case study is to classify annual members and casual riders, and use the insights gained to create a marketing strategy to turn more casual riders into annual members.
# * **How can your insights drive business decisions?**
#
# The information gathered can be useful for marketing purposes. The insights can help increase the amount of annual members.
#
# ### Key Tasks:
# * **Identify the business task.**
# * **Consider key stakeholders.**
#
# ### Deliverable:
# * **A clear statement of the business task**
#
# Analyze the difference between annual members and casual riders and determine which marketing strategy to pursue to increase annual members.

# %% [markdown]
# # Prepare
#
# ### Guiding Questions:
# * **Where is your data located?**
#
# The data is located in on kaggle as a dataset titled "2020-trip-data".
# * **How is the data organized?**
#
# There are ten files. The files are seperated by month. January, February, and March are combined into a file titled "Divvy_Trips_2020_Q1.csv". The remaining months are seperated into their corresponding files.
# * **Are there issues with bias or credibility in this data? Does your data ROCCC?**
#
# The data is considered first-party due to it coming directly from Cyclist. This means that there is a low chance of bias, and the credibility being very high. Yes, the data does ROCCC. It is reliable, original, comprehensive, current, and cited.
# * **How are you addressing licensing, privacy, security, and accessibility?**
#
# The data is open source and provided by the company. Privacy is secure because the data does not contain any of the rider's personal information. The data is also covered by this license. https://www.divvybikes.com/data-license-agreement
# * **How did you verify the data's integrity?**
#
# After examining the data, it was determined that all of the data is consistent regarding the columns, data types, etc.
# * **How does the data help you answer your question?**
#
# The data allows us to determine characteristics between casual riders and annual members.
# * **Are there any problems with the data?**
#
# Overall the data is well rounded. The only improvement would be to add more information to each datatype.
#
# ### Key Tasks:
# * **Download data and store it appropriately**
# * **Identify how the data is organized**
# * **Sort and filter the data**
# * **Determine the credibility of the data**
#
# ### Deliverable:
# * **A description of all data sources used**
#
# The data source contains ten files. The files are seperated by month. January, February, and March are combined into a file titled "Divvy_Trips_2020_Q1.csv". The remaining months are seperated into their corresponding files. The data was recorded from January 2020 to December 2020.

# %% [markdown]
# # Process
# ### Guiding Questions:
# * **What tools are you choosing and why?**
#
# I have chosen to use R due to it's capabilities to perform indepth analysis and manipulation of large datasets.
# * **Have you ensured your data's integrity?**
#
# Yes, the columns and datatypes remained consistent after manipulation.
# * **What steps have you taken to ensure that your data is clean?**
#
# I removed the null values and duplicates. I also adjusted the format of the date and time datatypes.
# * **How can you verify that your data is clean and ready to analyze?**
#
# Ensure that the data is consistent and contains the data you need with no unnecessary datatypes.
# * **Have you documented your cleaning process so you can review and share those results?**
#
# Yes, the cleaning process is documented throughout.
# ### Key Tasks:
# * **Check the data for errors.**
# * **Choose your tools.**
# * **Transform the data so you can work with it effectively.**
# * **Document the cleaning process.**
# ### Deliverable:
# * **Documentation of any cleaning or manipulation of data**
#
# See the steps of the cleaning process below.

# %%
library(tidyverse)
library(janitor)
library(lubridate)
library(ggplot2)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test

# %% [markdown]
# #### Import individual CSV files

# %%
tripdata_2020_Q1 <- read.csv("/kaggle/input/2020-trip-data/Divvy_Trips_2020_Q1.csv")
tripdata_202004 <- read.csv("/kaggle/input/2020-trip-data/202004-divvy-tripdata.csv")
tripdata_202005 <- read.csv("/kaggle/input/2020-trip-data/202005-divvy-tripdata.csv")
tripdata_202006 <- read.csv("/kaggle/input/2020-trip-data/202006-divvy-tripdata.csv")
tripdata_202007 <- read.csv("/kaggle/input/2020-trip-data/202007-divvy-tripdata.csv")
tripdata_202008 <- read.csv("/kaggle/input/2020-trip-data/202008-divvy-tripdata.csv")
tripdata_202009 <- read.csv("/kaggle/input/2020-trip-data/202009-divvy-tripdata.csv")
tripdata_202010 <- read.csv("/kaggle/input/2020-trip-data/202010-divvy-tripdata.csv")
tripdata_202011 <- read.csv("/kaggle/input/2020-trip-data/202011-divvy-tripdata.csv")
tripdata_202012 <- read.csv("/kaggle/input/2020-trip-data/202012-divvy-tripdata.csv")

# %% [markdown]
# #### Examine individual datasets

# %%
str(tripdata_2020_Q1)
str(tripdata_202004)
str(tripdata_202005)
str(tripdata_202006)
str(tripdata_202007)
str(tripdata_202008)
str(tripdata_202009)
str(tripdata_202010)
str(tripdata_202011)
str(tripdata_202012)
# Out:
# 'data.frame':	426887 obs. of  13 variables:
#  $ ride_id           : chr  "EACB19130B0CDA4A" "8FED874C809DC021" "789F3C21E472CA96" "C9A388DAC6ABF313" ...
#  $ rideable_type     : chr  "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : chr  "2020-01-21 20:06:59" "2020-01-30 14:22:39" "2020-01-09 19:29:26" "2020-01-06 16:17:07" ...
#  $ ended_at          : chr  "2020-01-21 20:14:30" "2020-01-30 14:26:22" "2020-01-09 19:32:17" "2020-01-06 16:25:56" ...
#  $ start_station_name: chr  "Western Ave & Leland Ave" "Clark St & Montrose Ave" "Broadway & Belmont Ave" "Clark St & Randolph St" ...
#  $ start_station_id  : int  239 234 296 51 66 212 96 96 212 38 ...
#  $ end_station_name  : chr  "Clark St & Leland Ave" "Southport Ave & Irving Park Rd" "Wilton Ave & Belmont Ave" "Fairbanks Ct & Grand Ave" ...
#  $ end_station_id    : int  326 318 117 24 212 96 212 212 96 100 ...
#  $ start_lat         : num  42 42 41.9 41.9 41.9 ...
# ...

# %% [markdown]
# #### Changes needed after examining:
# * Both start_station_id and end-station_id colums are not uniformed datatypes throughout the dataset so that needs to be adjusted.
# * Issue in "tripdata_202012". start_station_id and end_station_id are char instead of int.

# %%
#Change start_station_id from char to int
options(warn=-1)

tripdata_202012 <- mutate(tripdata_202012, start_station_id = as.integer(start_station_id))

#Change end_station_id from char to int
tripdata_202012 <- mutate(tripdata_202012, end_station_id = as.integer(end_station_id))

# %%
str(tripdata_2020_Q1)
str(tripdata_202004)
str(tripdata_202005)
str(tripdata_202006)
str(tripdata_202007)
str(tripdata_202008)
str(tripdata_202009)
str(tripdata_202010)
str(tripdata_202011)
str(tripdata_202012)
# Out:
# 'data.frame':	426887 obs. of  13 variables:
#  $ ride_id           : chr  "EACB19130B0CDA4A" "8FED874C809DC021" "789F3C21E472CA96" "C9A388DAC6ABF313" ...
#  $ rideable_type     : chr  "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : chr  "2020-01-21 20:06:59" "2020-01-30 14:22:39" "2020-01-09 19:29:26" "2020-01-06 16:17:07" ...
#  $ ended_at          : chr  "2020-01-21 20:14:30" "2020-01-30 14:26:22" "2020-01-09 19:32:17" "2020-01-06 16:25:56" ...
#  $ start_station_name: chr  "Western Ave & Leland Ave" "Clark St & Montrose Ave" "Broadway & Belmont Ave" "Clark St & Randolph St" ...
#  $ start_station_id  : int  239 234 296 51 66 212 96 96 212 38 ...
#  $ end_station_name  : chr  "Clark St & Leland Ave" "Southport Ave & Irving Park Rd" "Wilton Ave & Belmont Ave" "Fairbanks Ct & Grand Ave" ...
#  $ end_station_id    : int  326 318 117 24 212 96 212 212 96 100 ...
#  $ start_lat         : num  42 42 41.9 41.9 41.9 ...
# ...

# %%
#Combine individual files into one
tripdata_2020 <- rbind(tripdata_2020_Q1, tripdata_202004, tripdata_202005, tripdata_202006, tripdata_202007, tripdata_202008, tripdata_202009, tripdata_202010, tripdata_202011, tripdata_202012)

# %%
#Confirming the total number of rows for the individual dataframes
rowtotal <- sum(
nrow(tripdata_2020_Q1),
nrow(tripdata_202004),
nrow(tripdata_202005),
nrow(tripdata_202006),
nrow(tripdata_202007),
nrow(tripdata_202008),
nrow(tripdata_202009),
nrow(tripdata_202010),
nrow(tripdata_202011),
nrow(tripdata_202012))

print(rowtotal)
# Out:
# [1] 3541683

# %%
#Confirming the total number of rows for the combined dataframe
print(nrow(tripdata_2020))
# Out:
# [1] 3541683

# %% [markdown]
# #### Examine the combined dataset

# %%
str(tripdata_2020)
head(tripdata_2020)
# Out:
# 'data.frame':	3541683 obs. of  13 variables:
#  $ ride_id           : chr  "EACB19130B0CDA4A" "8FED874C809DC021" "789F3C21E472CA96" "C9A388DAC6ABF313" ...
#  $ rideable_type     : chr  "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : chr  "2020-01-21 20:06:59" "2020-01-30 14:22:39" "2020-01-09 19:29:26" "2020-01-06 16:17:07" ...
#  $ ended_at          : chr  "2020-01-21 20:14:30" "2020-01-30 14:26:22" "2020-01-09 19:32:17" "2020-01-06 16:25:56" ...
#  $ start_station_name: chr  "Western Ave & Leland Ave" "Clark St & Montrose Ave" "Broadway & Belmont Ave" "Clark St & Randolph St" ...
#  $ start_station_id  : int  239 234 296 51 66 212 96 96 212 38 ...
#  $ end_station_name  : chr  "Clark St & Leland Ave" "Southport Ave & Irving Park Rd" "Wilton Ave & Belmont Ave" "Fairbanks Ct & Grand Ave" ...
#  $ end_station_id    : int  326 318 117 24 212 96 212 212 96 100 ...
#  $ start_lat         : num  42 42 41.9 41.9 41.9 ...
# ...

# %% [markdown]
# #### Data Cleaning
# The time format is yyyy-mm-dd hh:mm:ss. For deeper analysis it is best to format into individual columns and add a day of the week column.

# %%
tripdata_2020$date <- as.Date(tripdata_2020$started_at)
tripdata_2020$month <- format(as.Date(tripdata_2020$date), "%b")
tripdata_2020$day <- format(as.Date(tripdata_2020$date), "%d")
tripdata_2020$year <- format(as.Date(tripdata_2020$date), "%Y")
tripdata_2020$day_of_week <- format(as.Date(tripdata_2020$date), "%A")

# %%
head(tripdata_2020)
# Out:
#   ride_id          rideable_type started_at          ended_at
# 1 EACB19130B0CDA4A docked_bike   2020-01-21 20:06:59 2020-01-21 20:14:30
# 2 8FED874C809DC021 docked_bike   2020-01-30 14:22:39 2020-01-30 14:26:22
# 3 789F3C21E472CA96 docked_bike   2020-01-09 19:29:26 2020-01-09 19:32:17
# 4 C9A388DAC6ABF313 docked_bike   2020-01-06 16:17:07 2020-01-06 16:25:56
# 5 943BC3CBECCFD662 docked_bike   2020-01-30 08:37:16 2020-01-30 08:42:48
# 6 6D9C8A6938165C11 docked_bike   2020-01-10 12:33:05 2020-01-10 12:37:54
#   start_station_name       start_station_id end_station_name
# 1 Western Ave & Leland Ave 239              Clark St & Leland Ave
# 2 Clark St & Montrose Ave  234              Southport Ave & Irving Park Rd
# 3 Broadway & Belmont Ave   296              Wilton Ave & Belmont Ave
# 4 Clark St & Randolph St    51              Fairbanks Ct & Grand Ave
# 5 Clinton St & Lake St      66              Wells St & Hubbard St
# ...

# %% [markdown]
# #### To further clean we will remove all NA's and duplicate cells

# %%
#Remove NA's
tripdata_2020 <- drop_na(tripdata_2020)

# %%
#Remove duplicates from dataframe
tripdata_2020_no_duplicates <- tripdata_2020[!duplicated(tripdata_2020$ride_id), ]
print(paste("Removed", nrow(tripdata_2020) - nrow(tripdata_2020_no_duplicates), "duplicate rows"))
# Out:
# [1] "Removed 44 duplicate rows"

# %% [markdown]
# #### Data Manipulation

# %%
#Create a column to determine ride length
tripdata_2020_v2 <- mutate(tripdata_2020_no_duplicates, ride_length = difftime(ended_at, started_at, units = "mins"))
str(tripdata_2020_v2)
# Out:
# 'data.frame':	3298800 obs. of  19 variables:
#  $ ride_id           : chr  "EACB19130B0CDA4A" "8FED874C809DC021" "789F3C21E472CA96" "C9A388DAC6ABF313" ...
#  $ rideable_type     : chr  "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : chr  "2020-01-21 20:06:59" "2020-01-30 14:22:39" "2020-01-09 19:29:26" "2020-01-06 16:17:07" ...
#  $ ended_at          : chr  "2020-01-21 20:14:30" "2020-01-30 14:26:22" "2020-01-09 19:32:17" "2020-01-06 16:25:56" ...
#  $ start_station_name: chr  "Western Ave & Leland Ave" "Clark St & Montrose Ave" "Broadway & Belmont Ave" "Clark St & Randolph St" ...
#  $ start_station_id  : int  239 234 296 51 66 212 96 96 212 38 ...
#  $ end_station_name  : chr  "Clark St & Leland Ave" "Southport Ave & Irving Park Rd" "Wilton Ave & Belmont Ave" "Fairbanks Ct & Grand Ave" ...
#  $ end_station_id    : int  326 318 117 24 212 96 212 212 96 100 ...
#  $ start_lat         : num  42 42 41.9 41.9 41.9 ...
# ...

# %%
#Filter out trips with a ride length less than 0
nrow(tripdata_2020_v2[tripdata_2020_v2$ride_length < 0,])
tripdata_2020_v3 <- tripdata_2020_v2[!tripdata_2020_v2$ride_length < 0,]
glimpse(tripdata_2020_v3)
# Out:
# [1] 10233
# Rows: 3,288,567
# Columns: 19
# $ ride_id            <chr> "EACB19130B0CDA4A", "8FED874C809DC021", "789F3C21E4…
# $ rideable_type      <chr> "docked_bike", "docked_bike", "docked_bike", "docke…
# $ started_at         <chr> "2020-01-21 20:06:59", "2020-01-30 14:22:39", "2020…
# $ ended_at           <chr> "2020-01-21 20:14:30", "2020-01-30 14:26:22", "2020…
# $ start_station_name <chr> "Western Ave & Leland Ave", "Clark St & Montrose Av…
# $ start_station_id   <int> 239, 234, 296, 51, 66, 212, 96, 96, 212, 38, 117, 1…
# $ end_station_name   <chr> "Clark St & Leland Ave", "Southport Ave & Irving Pa…
# $ end_station_id     <int> 326, 318, 117, 24, 212, 96, 212, 212, 96, 100, 632,…
# $ start_lat          <dbl> 41.9665, 41.9616, 41.9401, 41.8846, 41.8856, 41.889…
# $ start_lng          <dbl> -87.6884, -87.6660, -87.6455, -87.6319, -87.6418, -…
# $ end_lat            <dbl> 41.9671, 41.9542, 41.9402, 41.8918, 41.8899, 41.884…
# ...

# %%
#Determine the amount of members vs casual riders
rider_type_total <- table(tripdata_2020_v3$member_casual)
View(rider_type_total)
# Out:
#  casual  member
# 1278811 2009756

# %% [markdown]
# # Analyze
# ### Guiding Questions:
# * **How should you organize your data to perform analysis on it?**
#
# The data should be organized to best compare the differences between casual riders and annual members.
# * **Has your data been properly formatted?**
#
# Yes, the data has been properly formatted.
# * **What surprises did you find in your data?**
#
# Casual riders had a longer average ride length than members.
# * **What trends or relationships did you find in the data?**
#
# See the summary of the analysis.
# * **How will these insights help answer your business questions?**
# ### Key Tasks:
# * **Aggregate your data so it's useful and accessible.**
# * **Organize and format your data.**
# * **Perform calculations.**
# * **Identify trends and relationships.**
# ### Deliverable:
# * **A summary of your analysis**
#
# * There were more members(2009756) than casual riders(1278811) in the year 2020.
#
# * Casual riders(48.27 mins) had a higher average ride length than members(15.75 mins).
#
# * Casual riders had the longest ride time being 156450.40 mins or 2608 hours.
#
# * The most popular day for bike sharing was Saturday.
#
# * The most popular day for casual riders was Saturday with an average ride length of 49.18 mins.
#
# * The most popular day for members was Wednesday with an average ride length of 14.73 mins
#
# * The most popular month was August with 605746 rides with an average ride duration of 29.45 mins.
#
# * The least popular month was December with 23295 rides with an average ride duration of 17.90 mins.
#
# * The most popular start station overall was "Streeter Dr & Grand Ave".
#
# * The most popular start station for members was "Clark St & Elm St" with 19195 trips starting from here.
#
# * The most popular start station for casual riders was "Streeter Dr & Grand Ave" with 25790 trips starting from here.

# %%
#Statistical analysis
trip_stats <- tripdata_2020_v3 %>%
    group_by(member_casual) %>%
    summarise(average_ride_length = mean(ride_length), standard_deviation = sd(ride_length), median_ride_length = median(ride_length), min_ride_length = min(ride_length), max_ride_length = max(ride_length))
head(trip_stats)
# Out:
#   member_casual average_ride_length standard_deviation median_ride_length
# 1 casual        48.26846 mins       513.9073           22.06667 mins
# 2 member        15.75257 mins       135.1715           11.23333 mins
#   min_ride_length max_ride_length
# 1 0 mins          156450.40 mins
# 2 0 mins           93793.52 mins

# %% [markdown]
# #### Create function to determoine the mode for the day of the week

# %%
getmode <- function(v) {
    uniqv <- unique(v)
    uniqv[which.max(tabulate(match(v, uniqv)))]
}

weekday_mode <- getmode(tripdata_2020_v3$day_of_week)

print(weekday_mode)
# Out:
# [1] "Saturday"

# %% [markdown]
# #### Analysis
# Determine which days had the most rides, and average ride length for each rider type.

# %%
#Determine the most popular day by rider type
tripdata_2020_v3$day_of_week <- ordered(tripdata_2020_v3$day_of_week, levels = c("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"))

tripdata_2020_v3 %>%
    group_by(member_casual, day_of_week) %>%
    summarise(rider_type_total = n(), average_ride_length = mean(ride_length)) %>%
arrange(member_casual, day_of_week)
# Out:
# `summarise()` has grouped output by 'member_casual'. You can override using the
# `.groups` argument.
#    member_casual day_of_week rider_type_total average_ride_length
# 1  casual        Monday      131841           47.31794 mins
# 2  casual        Tuesday     127458           43.62078 mins
# 3  casual        Wednesday   141078           43.62189 mins
# 4  casual        Thursday    150554           47.54290 mins
# 5  casual        Friday      189172           46.16261 mins
# 6  casual        Saturday    296820           49.18459 mins
# 7  casual        Sunday      241888           54.91994 mins
# 8  member        Monday      270122           14.96700 mins
# 9  member        Tuesday     290133           14.53046 mins
# 10 member        Wednesday   303579           14.73450 mins
# 11 member        Thursday    302916           14.73337 mins
# 12 member        Friday      302917           15.46833 mins
# 13 member        Saturday    289554           17.95128 mins
# ...

# %%
#Determine the most popular months during 2020
popular_month <- tripdata_2020_v3 %>%
    group_by(month) %>%
    summarise(number_of_rides = n(), average_duration = mean(ride_length)) %>%
    arrange(-number_of_rides)

View(popular_month)
# Out:
#    month number_of_rides average_duration
# 1  Aug   605746          29.45476 mins
# 2  Jul   548681          37.95560 mins
# 3  Sep   498263          25.24794 mins
# 4  Jun   342069          33.28887 mins
# 5  Oct   337400          20.23304 mins
# 6  Nov   221935          20.05132 mins
# 7  May   199782          33.04914 mins
# 8  Jan   143884          19.29203 mins
# 9  Mar   143302          23.73149 mins
# 10 Feb   139584          23.38450 mins
# 11 Apr    84626          35.60738 mins
# 12 Dec    23295          17.89633 mins

# %%
#Determine the most popular start station
station_mode <- getmode(tripdata_2020_v3$start_station_name)

print(station_mode)
# Out:
# [1] "Streeter Dr & Grand Ave"

# %%
#Determine the most popular start station for members
popular_start_stations_member <- tripdata_2020_v3 %>%
    filter(member_casual == 'member') %>%
    group_by(start_station_name) %>%
    summarise(number_of_starts = n()) %>%
    filter(start_station_name != "") %>%
    arrange(- number_of_starts)
head(popular_start_stations_member)
# Out:
#   start_station_name       number_of_starts
# 1 Clark St & Elm St        19195
# 2 Kingsbury St & Kinzie St 15610
# 3 St. Clair St & Erie St   15309
# 4 Broadway & Barry Ave     15231
# 5 Dearborn St & Erie St    15203
# 6 Wells St & Concord Ln    14625

# %%
#Determine the most popular start station for casual riders
popular_start_stations_casual <- tripdata_2020_v3 %>%
    filter(member_casual == 'casual') %>%
    group_by(start_station_name) %>%
    summarise(number_of_starts = n()) %>%
    filter(start_station_name != "") %>%
    arrange(- number_of_starts)

head(popular_start_stations_casual)
# Out:
#   start_station_name         number_of_starts
# 1 Streeter Dr & Grand Ave    25790
# 2 Lake Shore Dr & Monroe St  19751
# 3 Millennium Park            18275
# 4 Theater on the Lake        14394
# 5 Michigan Ave & Oak St      13092
# 6 Lake Shore Dr & North Blvd 12713

# %% [markdown]
# #### Save clean data as CSV to be uploaded to tableau.

# %%
tripdata_2020_v3 %>%
    write.csv("tripdata_2020_clean.csv")

# %% [markdown]
# # Share
# ### Guiding Questions:
# * **Were you able to answer the question of how annual members and casual riders use Cyclistic bikes differently?**
#
# Yes, I found a number of differences in uses between casual riders and annual members.
# * **What story does your data tell?**
#
# Based on the analysis, we can determine that there is a large number of casual riders who have a higher average ride duration. This is a good target for the digital marketing campaign.
# * **How do your findings relate to your original question?**
#
# We found the differences in bike use between the casual riders and annual members. We found a potential target for the marketing campaign.
# * **Who is your audience? What is the best way to communicate with them?**
#
# The audience is the key stakeholders that were mentioned in the beginning of the case study. The best way to communicate to them is to show give a brief explenation of data analysis process and show them the data visualizations to back it up.
# * **Can data visualization help you share your findings?**
#
# Absolutely, data visualizations make it much easier for the audience to grasp the concepts of the analysis findings.
# * **Is your presentation accessible to your audience?**
#
# This notebook with the entire data analysis process is accessible.
# ### Key Tasks:
# * **Determine the best way to share your findings.**
# * **Create effective data visualizations.**
# * **Present your findings.**
# * **Ensure your work is accessible.**
# ### Deliverable:
# * **Supporting visualizations and key findings**
#
# See the data visualizations below.

# %% [markdown]
# #### Data visualization using R

# %%
#Visualization of rider types
tripdata_2020_v3 %>%
    group_by(member_casual) %>%
    summarise(total_rider_type = n()) %>%
    ggplot(aes(x = member_casual, y = total_rider_type, fill = member_casual)) +
    geom_col(position = "dodge") + geom_text(aes(label = total_rider_type, vjust = -0.25))

# %%
#Visualization of rider types ride duration
rider_type_average_duration <- tripdata_2020_v3 %>%
    group_by(member_casual) %>%
    summarise(average_ride_length = mean(ride_length))

rider_type_average_duration %>%
    ggplot(aes(x = member_casual, y = average_ride_length, fill = member_casual)) +
    geom_col(position = "dodge") + geom_text(aes(label = average_ride_length, vjust = -0.25))
# Out:
# Don't know how to automatically pick scale for object of type <difftime>.
# Defaulting to continuous.
# Don't know how to automatically pick scale for object of type <difftime>.
# Defaulting to continuous.

# %%
#Visualization of the usage by members and casual riders by day
tripdata_2020_v3 %>%
    group_by(member_casual, day_of_week) %>%
    summarise(number_of_rides = n(), average_duration = mean(ride_length)) %>%
    arrange(member_casual, day_of_week) %>%
    ggplot(aes(x = day_of_week, y = average_duration, fill = member_casual)) +
    geom_col(position = "dodge")
# Out:
# `summarise()` has grouped output by 'member_casual'. You can override using the
# `.groups` argument.
# Don't know how to automatically pick scale for object of type <difftime>.
# Defaulting to continuous.

# %%
#Visualization of the number of trips by members and casual riders by the day
tripdata_2020_v3 %>%
    group_by(member_casual, day_of_week) %>%
    summarise(number_of_rides = n(), average_duration = mean(ride_length)) %>%
    arrange(member_casual, day_of_week) %>%
    ggplot(aes(x = day_of_week, y = number_of_rides, fill = member_casual)) +
    geom_col(position = "dodge")
# Out:
# `summarise()` has grouped output by 'member_casual'. You can override using the
# `.groups` argument.

# %%
#Visualization of the usage by members and casual riders by month
tripdata_2020_v3$month <- ordered(tripdata_2020_v3$month, levels=c("Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"))

tripdata_2020_v3 %>% 
  group_by(member_casual, month) %>% 
  summarise(number_of_rides = n(),average_duration = mean(ride_length) ) %>% 
  arrange(member_casual, month)  %>% 
  ggplot(aes(x = month, y = average_duration, fill = member_casual)) +
  geom_col(position = "dodge") +
  geom_text(aes(label = number_of_rides, angle = 90)) +
  facet_wrap(~member_casual)
# Out:
# `summarise()` has grouped output by 'member_casual'. You can override using the
# `.groups` argument.
# Don't know how to automatically pick scale for object of type <difftime>.
# Defaulting to continuous.

# %%
#Visualization of the number of trips by members and casual riders by month

tripdata_2020_v3 %>% 
  group_by(member_casual, month) %>% 
  summarise(number_of_rides = n()) %>% 
  arrange(member_casual, month)  %>% 
  ggplot(aes(x = month, y = number_of_rides, fill = member_casual)) +
  geom_col(position = "dodge") +
  geom_text(aes(label = number_of_rides, angle = 90)) +
  facet_wrap(~member_casual)
# Out:
# `summarise()` has grouped output by 'member_casual'. You can override using the
# `.groups` argument.

# %% [markdown]
# # Act
# ### Guiding Questions:
# * **What is your final conclusion based on your analysis?**
#
# Based on the analysis there is an opportunity to turn casual riders into annual members. As stated previously, there is a large number of casual riders who use the bikes more than annual members. This means there is a large pool of people that a digital marketing campaign could convert to annual members.
# * **How could your team and business apply your insights?**
#
# The best way to apply these insights is to launch a digital marketing campaign to target long use casual riders. The campaign should focus on the benefits of being an annual member over a casual member for longer rides.
# * **What next steps would you or your stakeholders take based on your findings?**
#
# I would possibly recommend doing a more in-depth analysis of long use rides specifically, and the corresponding benefits of being an annual member.
# * **Is there additional data you could use to expand on your findings?**
#
# Some additional data that could enhance results includes demographic data, climate data, financial data, etc.
# ### Key Tasks:
# * **Create your portfolio.**
# * **Add your case study.**
# * **Practice presenting your case study to a friend or family member.**
# ### Deliverable:
# * **Your top three recommendations based on your analysis**
#
# 1. Launch the digital marketing campaign to show casual riders the perks of being an annual member.
# 2. Launch an ad campaign at the popular start stations to increase engagement for memberships.
# 3. Another campaign could target the annual members in an attempt to increase usage during the slower months.
